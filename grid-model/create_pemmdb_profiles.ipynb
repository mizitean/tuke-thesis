# %% [markdown]
# # Generate PEMMDB Profiles — `my_pemmdb_profiles_2030.nc`
#
# This notebook generates `data/open-tyndp/my_pemmdb_profiles_2030.nc` from PEMMDB2 Excel files
# provided by ENTSO-E as part of the TYNDP 2024 dataset, and then analyses the structure
# and content of the resulting dataset.
#
# **Inputs:**
# - `data/tyndp2024/PEMMDB2/2030/*.xlsx` — PEMMDB2 Excel files (one per node)
# - `data/open-tyndp/tyndp_technology_map.csv` — technology → open-tyndp carrier mapping
# - `data/open-tyndp/buses.csv` — network node list
#
# **Outputs:**
# - `data/open-tyndp/my_pemmdb_profiles_2030.nc` — hourly `p_min_pu` and `p_max_pu` profiles (CY2009, 8760 h)
# - `data/open-tyndp/my_pemmdb_capacities_2030.csv` — installed capacities (MW / MWh) per node and carrier

# %% [markdown]
# ## 1. Configuration

# %%
import sys
import logging
import types
import importlib.util
from pathlib import Path
from functools import partial
from itertools import product

import numpy as np
import pandas as pd
import xarray as xr
from tqdm.notebook import tqdm

# Paths
BASE_DIR        = Path("..").resolve()
PEMMDB_DIR      = BASE_DIR / "data/tyndp2024/PEMMDB2"   # script appends /{pyear}/ internally
CARRIER_MAP_CSV = BASE_DIR / "data/open-tyndp/tyndp_technology_map.csv"
OUT_PROFILES    = BASE_DIR / "data/open-tyndp/my_pemmdb_profiles_2030.nc"
OUT_CAPACITIES  = BASE_DIR / "data/open-tyndp/my_pemmdb_capacities_2030.csv"

# Parameters
CYEAR          = 2009    # climate year (CY2009 used throughout TYNDP 2024)
PYEAR          = 2030    # planning year
PYEAR_I        = 2030
TYNDP_SCENARIO = "NT"   # National Trends scenario

# Technologies to process (mirrors open-tyndp NT config)
PEMMDB_TECHS = [
    "Nuclear", "Hard coal", "Lignite", "Gas", "Light oil", "Heavy oil", "Oil shale",
    "Hydrogen", "Other Non-RES", "DSR", "Other RES", "Battery", "Hydro",
]

print(f"BASE_DIR    : {BASE_DIR}")
print(f"PEMMDB_DIR  : {PEMMDB_DIR}")
print(f"Out profiles: {OUT_PROFILES}")
print(f"Out caps    : {OUT_CAPACITIES}")
# Out:
# BASE_DIR    : /Users/radovanhodor/Documents/TUKE/Final diplomova praca
# PEMMDB_DIR  : /Users/radovanhodor/Documents/TUKE/Final diplomova praca/data/tyndp2024/PEMMDB2
# Out profiles: /Users/radovanhodor/Documents/TUKE/Final diplomova praca/data/open-tyndp/my_pemmdb_profiles_2030.nc
# Out caps    : /Users/radovanhodor/Documents/TUKE/Final diplomova praca/data/open-tyndp/my_pemmdb_capacities_2030.csv

# %% [markdown]
# ## 2. Load `build_pemmdb_data.py` helper module
#
# The open-tyndp script `build_pemmdb_data.py` uses `from scripts._helpers import ...`.
# We shim that import so the module loads without the full Snakemake project structure.

# %%
logging.basicConfig(level=logging.WARNING, format="%(levelname)s - %(message)s")

GRID_MODEL_DIR = BASE_DIR / "grid-model"
if str(GRID_MODEL_DIR) not in sys.path:
    sys.path.insert(0, str(GRID_MODEL_DIR))

# --- Mock scripts._helpers ---
# build_pemmdb_data.py imports only these 6 symbols from scripts._helpers.
# We define them directly here to avoid loading the full _helpers.py
# (which requires atlite, fiona, git, pypsa, etc.).

from bisect import bisect_right

def configure_logging(snakemake, skip_handlers=False):
    logging.basicConfig(level=logging.WARNING)

def set_scenario_config(snakemake):
    pass

def get_snapshots(snapshots, drop_leap_day=False, freq="h", **kwargs):
    start = snapshots["start"] if isinstance(snapshots["start"], list) else [snapshots["start"]]
    end   = snapshots["end"]   if isinstance(snapshots["end"],   list) else [snapshots["end"]]
    time  = pd.DatetimeIndex([])
    for s, e in zip(start, end):
        period = pd.date_range(start=s, end=e, freq=freq, inclusive=snapshots["inclusive"], **kwargs)
        time = time.append(period)
    if drop_leap_day and time.is_leap_year.any():
        time = time[~((time.month == 2) & (time.day == 29))]
    return time

def safe_pyear(year, available_years=[2030, 2040, 2050], source="TYNDP", verbose=True):
    if not isinstance(year, int):
        year = int(year)
    if year not in available_years:
        year_new = available_years[bisect_right(sorted(available_years), year, lo=1) - 1]
        if verbose:
            logging.warning(f"{source} data unavailable for {year}. Falling back to {year_new}.")
        return year_new
    return year

def map_tyndp_carrier_names(df, carrier_mapping_fn, on_columns, drop_on_columns=False):
    carrier_mapping = (
        pd.read_csv(carrier_mapping_fn)[on_columns + ["open_tyndp_carrier", "open_tyndp_index", "open_tyndp_type"]]
    ).dropna()
    df = df.merge(carrier_mapping, on=on_columns, how="left")
    if "pemmdb_carrier" in on_columns:
        def normalize_carrier(s):
            return s.lower().replace(" ", "-").replace("other-non-res", "chp")
        df = df.assign(
            open_tyndp_carrier=lambda x: np.where(
                x["pemmdb_carrier"].isin(["DSR", "Other Non-RES"]),
                x["pemmdb_carrier"].apply(normalize_carrier),
                x["open_tyndp_carrier"],
            ),
            open_tyndp_index=lambda x: np.where(
                x["pemmdb_carrier"].isin(["DSR", "Other Non-RES"]),
                x["open_tyndp_carrier"] + "-" + x["pemmdb_type"].apply(normalize_carrier),
                x["open_tyndp_index"],
            ),
        )
    if not drop_on_columns:
        return df
    df = df.drop(on_columns, axis="columns").rename(
        columns={"open_tyndp_carrier": "carrier", "open_tyndp_index": "index_carrier"}
    )
    cols = ["carrier", "index_carrier"] + [c for c in df.columns if c not in ["carrier", "index_carrier"]]
    return df[cols]

def convert_units(df, unit_col="unit", value_col="value", invert=False):
    return df

def mock_snakemake(*args, **kwargs):
    raise NotImplementedError("mock_snakemake not needed in notebook mode")

# Register as scripts._helpers
scripts_pkg = types.ModuleType("scripts")
scripts_pkg.__path__ = [str(GRID_MODEL_DIR)]
scripts_pkg.__package__ = "scripts"
sys.modules["scripts"] = scripts_pkg

helpers_mod = types.ModuleType("scripts._helpers")
helpers_mod.configure_logging    = configure_logging
helpers_mod.set_scenario_config  = set_scenario_config
helpers_mod.get_snapshots        = get_snapshots
helpers_mod.safe_pyear           = safe_pyear
helpers_mod.map_tyndp_carrier_names = map_tyndp_carrier_names
helpers_mod.convert_units        = convert_units
helpers_mod.mock_snakemake       = mock_snakemake
sys.modules["scripts._helpers"]  = helpers_mod

# Load build_pemmdb_data
spec2 = importlib.util.spec_from_file_location(
    "build_pemmdb_data",
    GRID_MODEL_DIR / "build_pemmdb_data.py",
)
bpd = importlib.util.module_from_spec(spec2)
bpd.__name__ = "build_pemmdb_data"
spec2.loader.exec_module(bpd)

print("build_pemmdb_data loaded successfully")
print(f"PEMMDB_SHEET_MAPPING keys: {list(bpd.PEMMDB_SHEET_MAPPING.keys())}")
# Out:
# build_pemmdb_data loaded successfully
# PEMMDB_SHEET_MAPPING keys: ['Gas', 'Nuclear', 'Hard coal', 'Lignite', 'Light oil', 'Heavy oil', 'Oil shale', 'Hydrogen']

# %% [markdown]
# ## 3. Discover nodes and prepare snapshots

# %%
# Hourly snapshots for climate year
sns = pd.date_range(start=f"{CYEAR}-01-01", end=f"{CYEAR+1}-01-01", freq="h", inclusive="left")
sns_year_h = sns
print(f"Snapshots: {len(sns)} hours  ({sns[0]} → {sns[-1]})")

# Discover nodes from available PEMMDB Excel files
pemmdb_year_dir = PEMMDB_DIR / str(PYEAR)
pemmdb_files = sorted(pemmdb_year_dir.glob("PEMMDB_*_NationalTrends_2030.xlsx"))
nodes = pd.Index([f.stem.split("_")[1] for f in pemmdb_files])
print(f"\nFound {len(nodes)} nodes in {pemmdb_year_dir}:")
print(list(nodes))

# Determine which technology sheets to process
pemmdb_tech_sheets = list({bpd.PEMMDB_SHEET_MAPPING.get(t, t) for t in PEMMDB_TECHS})
thermal_techs = [k for k, v in bpd.PEMMDB_SHEET_MAPPING.items() if v == "Thermal"]
print(f"\nTechnology sheets to process: {pemmdb_tech_sheets}")
# Out:
# Snapshots: 8760 hours  (2009-01-01 00:00:00 → 2009-12-31 23:00:00)
#
# Found 77 nodes in /Users/radovanhodor/Documents/TUKE/Final diplomova praca/data/tyndp2024/PEMMDB2/2030:
# ['AL00', 'AT00', 'BA00', 'BE00', 'BEOF', 'BG00', 'CH00', 'CY00', 'CZ00', 'DE00', 'DEKF', 'DKBH', 'DKE1', 'DKKF', 'DKNS', 'DKW1', 'DZ00', 'EE00', 'EEOF', 'EG00', 'ES00', 'FI00', 'FR00', 'FR15', 'GE00', 'GR00', 'GR03', 'HR00', 'HU00', 'IE00', 'IL00', 'ITA00', 'ITCA', 'ITCN', 'ITCS', 'ITN1', 'ITS1', 'ITSA', 'ITSI', 'LT00', 'LTOF', 'LUB1', 'LUF1', 'LUG1', 'LUV1', 'LV00', 'LY00', 'MA00', 'MD00', 'ME00', 'MK00', 'MT00', 'NL00', 'NL60', 'NL6H', 'NLA0', 'NLBH', 'NLLL', 'NOM1', 'NON1', 'NOS0', 'PL00', 'PS00', 'PT00', 'RO00', 'RS00', 'SE01', 'SE02', 'SE03', 'SE04', 'SI00', 'SK00', 'TN00', 'TR00', 'UA00', 'UK00', 'UKNI']
#
# Technology sheets to process: ['Thermal', 'Battery', 'Other Non-RES', 'DSR', 'Hydro', 'Other RES']

# %% [markdown]
# ## 4. Load PEMMDB Excel files

# %%
func_read = partial(
    bpd.read_pemmdb_data,
    pemmdb_dir=str(PEMMDB_DIR),
    cyear=CYEAR,
    pyear=PYEAR,
    required_sheets=pemmdb_tech_sheets,
)

pemmdb_data = {}
for node in tqdm(nodes, desc="Loading PEMMDB Excel files"):
    result = func_read(node)
    if result is not None:
        pemmdb_data.update(result)

print(f"\nLoaded data for {len(pemmdb_data)} nodes")
# Out:
# Loading PEMMDB Excel files:   0%|          | 0/77 [00:00<?, ?it/s]
# Loaded data for 77 nodes

# %% [markdown]
# ## 5. Process capacities and profiles
#
# For each `(node, technology sheet)` combination, call `process_pemmdb_data` twice:
# once for `"capacities"` and once for `"profiles"`.
# Nodes/sheets that fail (e.g. missing Battery tabs for non-EU nodes) are skipped with a warning.

# %%
node_tech_sheets = list(product(nodes, pemmdb_tech_sheets))
print(f"Total (node, sheet) combinations: {len(node_tech_sheets)}")

process_kwargs = dict(
    pemmdb_data=pemmdb_data,
    thermal_techs=thermal_techs,
    cyear=CYEAR,
    pyear=PYEAR,
    pyear_i=PYEAR_I,
    tyndp_scenario=TYNDP_SCENARIO,
    sns=sns,
    sns_year_h=sns_year_h,
    carrier_mapping_fn=str(CARRIER_MAP_CSV),
)

# Capacities
pemmdb_capacities = []
skipped_caps = []
for nts in tqdm(node_tech_sheets, desc="Processing capacities"):
    try:
        result = bpd.process_pemmdb_data("capacities", node_tech_sheet=nts, **process_kwargs)
        if result is not None:
            pemmdb_capacities.append(result)
    except Exception as e:
        skipped_caps.append((nts, str(e)))

pemmdb_capacities_df = pd.concat(pemmdb_capacities, axis=0) if pemmdb_capacities else pd.DataFrame()
print(f"\nCapacities: {len(pemmdb_capacities_df)} rows  |  skipped: {len(skipped_caps)} combinations")

# Profiles
pemmdb_profiles = []
skipped_profs = []
for nts in tqdm(node_tech_sheets, desc="Processing profiles"):
    try:
        result = bpd.process_pemmdb_data("profiles", node_tech_sheet=nts, **process_kwargs)
        if result is not None:
            pemmdb_profiles.append(result)
    except Exception as e:
        skipped_profs.append((nts, str(e)))

pemmdb_profiles_df = pd.concat(pemmdb_profiles, axis=0) if pemmdb_profiles else pd.DataFrame()
print(f"Profiles  : {len(pemmdb_profiles_df)} rows  |  skipped: {len(skipped_profs)} combinations")
# Out:
# Total (node, sheet) combinations: 462
# Processing capacities:   0%|          | 0/462 [00:00<?, ?it/s]
# Capacities: 3215 rows  |  skipped: 9 combinations
# Processing profiles:   0%|          | 0/462 [00:00<?, ?it/s]
# Profiles  : 1638120 rows  |  skipped: 0 combinations

# %% [markdown]
# ## 6. Save outputs to disk

# %%
# Save capacities CSV
if not pemmdb_capacities_df.empty:
    pemmdb_capacities_df.to_csv(OUT_CAPACITIES, index=False)
    print(f"Saved capacities: {OUT_CAPACITIES}  ({len(pemmdb_capacities_df)} rows)")
else:
    print("WARNING: no capacity data to save")

# Build xarray Dataset and save NetCDF
if pemmdb_profiles_df.empty:
    print("WARNING: no profile data to save")
else:
    ds = xr.Dataset(
        {
            "p_min_pu": (["sample"], pemmdb_profiles_df["p_min_pu"].values),
            "p_max_pu": (["sample"], pemmdb_profiles_df["p_max_pu"].values),
        },
        coords={
            level: (["sample"], pemmdb_profiles_df.index.get_level_values(level))
            for level in pemmdb_profiles_df.index.names
        },
    )
    ds.to_netcdf(OUT_PROFILES)
    print(f"Saved profiles : {OUT_PROFILES}")
    print(f"  Size on disk : {OUT_PROFILES.stat().st_size / 1e6:.1f} MB")
# Out:
# Saved capacities: /Users/radovanhodor/Documents/TUKE/Final diplomova praca/data/open-tyndp/my_pemmdb_capacities_2030.csv  (3215 rows)
# Saved profiles : /Users/radovanhodor/Documents/TUKE/Final diplomova praca/data/open-tyndp/my_pemmdb_profiles_2030.nc
#   Size on disk : 431.8 MB

# %% [markdown]
# ## 7. Dataset Analysis — Structure and Features
#
# Reload the saved NetCDF and inspect its dimensions, coordinates, variables, carriers and time coverage.

# %%
# Reload saved dataset and print overview
ds = xr.open_dataset(OUT_PROFILES)
print("=== xarray Dataset overview ===")
print(ds)
# Out:
# === xarray Dataset overview ===
# <xarray.Dataset> Size: 531MB
# Dimensions:          (sample: 1638120)
# Coordinates:
#     time             (sample) datetime64[ns] 13MB ...
#     bus              (sample) <U4 26MB ...
#     carrier          (sample) <U9 59MB ...
#     index_carrier    (sample) <U53 347MB ...
#     open_tyndp_type  (sample) <U9 59MB ...
# Dimensions without coordinates: sample
# Data variables:
#     p_min_pu         (sample) float64 13MB ...
#     p_max_pu         (sample) float64 13MB ...

# %%
df = ds.to_dataframe().reset_index()

print("=== DataFrame shape and columns ===")
print(f"Shape  : {df.shape}")
print(f"Columns: {df.columns.tolist()}")
print()
print("=== Data types ===")
print(df.dtypes)
print()
print("=== First 5 rows ===")
df.head()
# Out:
# === DataFrame shape and columns ===
# Shape  : (1638120, 8)
# Columns: ['sample', 'p_min_pu', 'p_max_pu', 'time', 'bus', 'carrier', 'index_carrier', 'open_tyndp_type']
#
# === Data types ===
# sample                      int64
# p_min_pu                  float64
# p_max_pu                  float64
# time               datetime64[ns]
# bus                        object
# carrier                    object
# index_carrier              object
# open_tyndp_type            object
# dtype: object
#
# === First 5 rows ===
#    sample  p_min_pu  p_max_pu                time   bus carrier  \
# 0       0       0.0  0.549245 2009-01-01 00:00:00  AT00     chp
# 1       1       0.0  0.549245 2009-01-01 01:00:00  AT00     chp
# 2       2       0.0  0.549245 2009-01-01 02:00:00  AT00     chp
# 3       3       0.0  0.549245 2009-01-01 03:00:00  AT00     chp
# 4       4       0.0  0.549245 2009-01-01 04:00:00  AT00     chp
#
#                        index_carrier open_tyndp_type
# 0  chp-gas-ccgt-old-1-other-70.65eur
# 1  chp-gas-ccgt-old-1-other-70.65eur
# 2  chp-gas-ccgt-old-1-other-70.65eur
# 3  chp-gas-ccgt-old-1-other-70.65eur
# 4  chp-gas-ccgt-old-1-other-70.65eur

# %%
print("=== Unique values per coordinate ===")
print(f"time            : {df.time.nunique()} unique hours  ({df.time.min()} → {df.time.max()})")
print(f"bus             : {df.bus.nunique()} unique nodes")
print(f"carrier         : {sorted(df.carrier.unique())}")
print(f"open_tyndp_type : {sorted(df.open_tyndp_type.unique())}")
print(f"index_carrier   : {df.index_carrier.nunique()} unique sub-types")
# Out:
# === Unique values per coordinate ===
# time            : 8760 unique hours  (2009-01-01 00:00:00 → 2009-12-31 23:00:00)
# bus             : 50 unique nodes
# carrier         : ['chp', 'coal', 'dsr', 'gas', 'h2-ccgt', 'lignite', 'oil-heavy', 'oil-light', 'other-res', 'uranium']
# open_tyndp_type : ['', 'coal', 'gas-ccgt', 'gas-conv', 'gas-ocgt', 'h2-ccgt', 'lignite', 'nuclear', 'oil-heavy', 'oil-light', 'other-res']
# open_tyndp_type : ['', 'coal', 'gas-ccgt', 'gas-conv', 'gas-ocgt', 'h2-ccgt', 'lignite', 'nuclear', 'oil-heavy', 'oil-light', 'other-res']
# index_carrier   : 59 unique sub-types
# index_carrier   : 59 unique sub-types

# %%
print(df.index_carrier.nunique())
print(df.index_carrier.unique())
# Out:
# 59
# ['chp-gas-ccgt-old-1-other-70.65eur' 'other-res' 'gas-ccgt-present2'
#  'gas-conv-old2' 'coal-old2' 'chp-gas-conventional-old-2-industrial-0eur'
#  'dsr-4h-1500eur' 'gas-conv-old1' 'nuclear'
#  'chp-gas-conventional-old-1-industrial-0eur'
#  'chp-gas-conventional-old-1-other-0eur' 'chp-lignite-old-1-other-0eur'
#  'gas-ccgt-new' 'gas-ccgt-old2' 'gas-ccgt-present1' 'gas-ocgt-new'
#  'h2-ccgt' 'oil-light' 'chp-gas-conventional-old-1-other-128.4eur'
#  'dsr-24h-43.6eur' 'dsr-24h-87.1eur' 'gas-ccgt-old1' 'gas-ocgt-old'
#  'coal-new' 'coal-old1' 'oil-heavy-old1' 'dsr-24h-1000eur'
#  'chp-gas-ccgt-old-2-other-58.87500000000006eur'
#  'chp-gas-ccgt-old-1-other-0eur' 'chp-gas-conventional-old-2-other-0eur'
#  'dsr-12h-50eur' 'dsr-24h-75eur' 'dsr-2h-100eur' 'dsr-4h-150eur'
#  'chp-gas-ocgt-old-other-0eur'
#  'chp-gas-ocgt-old-other-82.34285714285716eur' 'dsr-10h-350eur'
#  'chp-gas-conventional-old-1-district-heatring-128.4eur' 'lignite-old1'
#  'chp--nan-0eur' 'chp-light-oil---industrial-0eur'
#  'chp-oil-shale-old-industrial-0eur' 'chp-heavy-oil-old-2-industrial-0eur'
#  'chp-heavy-oil-old-2-other-0eur' 'dsr-4h-500eur'
#  'chp-gas-ccgt-old-1-industrial-200eur'
#  'chp-gas-ccgt-old-1-industrial-520eur'
#  'chp-gas-ccgt-old-1-other-509.9999999999999eur'
#  'chp-gas-ccgt-old-1-other-530eur' 'chp-gas-ccgt-present-2-other-0eur'
#  'chp-gas-ccgt-present-2-other-79.69655172413793eur'
#  'chp-hard-coal-old-1-other-0eur'
#  'chp-hard-coal-old-1-other-93.18857142857145eur' 'lignite-old2'
#  'lignite-new' 'chp-gas-ccgt-old-2-other-0eur'
#  'chp-lignite-new-other-0eur' 'chp-conventional-old-1-nan-0eur'
#  'dsr-8h-500eur']

# %%
print(df.carrier.nunique())
print(df.carrier.unique())
# Out:
# 10
# ['chp' 'other-res' 'gas' 'coal' 'dsr' 'uranium' 'h2-ccgt' 'oil-light'
#  'oil-heavy' 'lignite']

# %%
print(df.open_tyndp_type.nunique())
print(df.open_tyndp_type.unique())
# Out:
# 11
# ['' 'other-res' 'gas-ccgt' 'gas-conv' 'coal' 'nuclear' 'gas-ocgt'
#  'h2-ccgt' 'oil-light' 'oil-heavy' 'lignite']

# %%
print("=== Per-carrier summary: row count, buses, p_min_pu and p_max_pu statistics ===")
print()
print(f"{'carrier':<14} {'open_tyndp_type':<20} {'rows':>8} {'buses':>6} "
      f"{'p_min mean':>10} {'p_min max':>10} {'p_max mean':>10} {'p_max<1 (%)':>12}")
print("-" * 100)

for (carrier, otype), grp in df.groupby(["carrier", "open_tyndp_type"]):
    rows     = len(grp)
    buses    = grp.bus.nunique()
    pm_mean  = grp.p_min_pu.mean()
    pm_max   = grp.p_min_pu.max()
    px_mean  = grp.p_max_pu.mean()
    px_lt1   = (grp.p_max_pu < 1.0).mean() * 100
    print(f"  {carrier:<14} {otype:<20} {rows:>8,} {buses:>6} "
          f"{pm_mean:>10.3f} {pm_max:>10.3f} {px_mean:>10.3f} {px_lt1:>11.1f}%")
# Out:
# === Per-carrier summary: row count, buses, p_min_pu and p_max_pu statistics ===
#
# carrier        open_tyndp_type          rows  buses p_min mean  p_min max p_max mean  p_max<1 (%)
# ----------------------------------------------------------------------------------------------------
#   chp                                  367,920     27      0.000      0.000      0.432        98.1%
#   coal           coal                  113,880      7      0.517      1.000      1.000         0.0%
#   dsr                                   96,360      7      0.000      0.000      0.502        84.3%
#   gas            gas-ccgt              332,880     23      0.232      0.963      1.000         0.0%
#   gas            gas-conv               96,360     10      0.359      1.000      1.000         0.0%
#   gas            gas-ocgt               87,600      6      0.438      0.961      1.000         0.0%
#   h2-ccgt        h2-ccgt                 8,760      1      0.047      0.047      1.000         0.0%
#   lignite        lignite                70,080      4      0.470      0.650      1.000         0.0%
#   oil-heavy      oil-heavy              17,520      2      0.305      0.706      1.000         0.0%
#   oil-light      oil-light               8,760      1      0.053      0.053      1.000         0.0%
#   other-res      other-res             394,200     45      0.601      1.000      1.000         0.0%
#   uranium        nuclear                43,800      5      0.871      1.000      1.000         0.0%
#   chp                                  367,920     27      0.000      0.000      0.432        98.1%
#   coal           coal                  113,880      7      0.517      1.000      1.000         0.0%
#   dsr                                   96,360      7      0.000      0.000      0.502        84.3%
#   gas            gas-ccgt              332,880     23      0.232      0.963      1.000         0.0%
#   gas            gas-conv               96,360     10      0.359      1.000      1.000         0.0%
#   gas            gas-ocgt               87,600      6      0.438      0.961      1.000         0.0%
#   h2-ccgt        h2-ccgt                 8,760      1      0.047      0.047      1.000         0.0%
#   lignite        lignite                70,080      4      0.470      0.650      1.000         0.0%
#   oil-heavy      oil-heavy              17,520      2      0.305      0.706      1.000         0.0%
#   oil-light      oil-light               8,760      1      0.053      0.053      1.000         0.0%
#   other-res      other-res             394,200     45      0.601      1.000      1.000         0.0%
#   uranium        nuclear                43,800      5      0.871      1.000      1.000         0.0%

# %% [markdown]
# ### Key finding: `p_max_pu` for thermal carriers
#
# For all dispatchable thermal carriers (`coal`, `gas`, `lignite`, `uranium`, `oil-*`, `h2-ccgt`)
# **`p_max_pu` is always 1.0** — PEMMDB does not encode planned or forced outage availability.
#
# The only carriers with meaningful `p_max_pu < 1` profiles are:
# - **`chp`** — upper bound set by heat demand (cogeneración dispatch)
# - **`dsr`** — demand side response availability window
#
# For thermal availability (outages), a separate source is needed (e.g. Plexos output).
# PEMMDB **does** provide useful **`p_min_pu`** (must-run obligations) for coal, gas, lignite, etc.

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# Monthly mean p_min_pu for key thermal carriers (carriers with non-zero p_min_pu)
thermal_plot = ['coal', 'lignite', 'gas', 'oil-heavy', 'chp', 'dsr']

fig, axes = plt.subplots(1, len(thermal_plot), figsize=(18, 4), sharey=False)
fig.suptitle("PEMMDB monthly mean p_min_pu by carrier (all buses averaged)", fontsize=13)

for ax, carrier in zip(axes, thermal_plot):
    sub = df[df.carrier == carrier].copy()
    sub['month'] = sub.time.dt.month
    monthly = sub.groupby('month')['p_min_pu'].mean()
    ax.bar(monthly.index, monthly.values, color='steelblue', edgecolor='white')
    ax.set_title(carrier)
    ax.set_xlabel("Month")
    ax.set_ylabel("mean p_min_pu")
    ax.set_ylim(0, 1)
    ax.xaxis.set_major_locator(mticker.MultipleLocator(2))

plt.tight_layout()
plt.show()

# %% [markdown]
# ```
# carrier: coal
#   └── open_tyndp_type: coal
#         ├── index_carrier: coal-old1
#         ├── index_carrier: coal-old2
#         └── index_carrier: coal-new
#
#
# carrier: gas
#   ├── open_tyndp_type: gas-ccgt
#   │     ├── index_carrier: gas-ccgt-old1
#   │     ├── index_carrier: gas-ccgt-old2
#   │     ├── index_carrier: gas-ccgt-new
#   │     └── index_carrier: gas-ccgt-present1
#   ├── open_tyndp_type: gas-conv
#   │     ├── index_carrier: gas-conv-old1
#   │     └── index_carrier: gas-conv-old2
#   └── open_tyndp_type: gas-ocgt
#         ├── index_carrier: gas-ocgt-old
#         └── index_carrier: gas-ocgt-new
# ```

# %%
df.head(100)
# Out:
#     sample  p_min_pu  p_max_pu                time   bus carrier  \
# 0        0       0.0  0.549245 2009-01-01 00:00:00  AT00     chp
# 1        1       0.0  0.549245 2009-01-01 01:00:00  AT00     chp
# 2        2       0.0  0.549245 2009-01-01 02:00:00  AT00     chp
# 3        3       0.0  0.549245 2009-01-01 03:00:00  AT00     chp
# 4        4       0.0  0.549245 2009-01-01 04:00:00  AT00     chp
# 5        5       0.0  0.549245 2009-01-01 05:00:00  AT00     chp
# 6        6       0.0  0.549245 2009-01-01 06:00:00  AT00     chp
# 7        7       0.0  0.549245 2009-01-01 07:00:00  AT00     chp
# 8        8       0.0  0.549245 2009-01-01 08:00:00  AT00     chp
# 9        9       0.0  0.549245 2009-01-01 09:00:00  AT00     chp
# 10      10       0.0  0.549245 2009-01-01 10:00:00  AT00     chp
# 11      11       0.0  0.549245 2009-01-01 11:00:00  AT00     chp
# 12      12       0.0  0.549245 2009-01-01 12:00:00  AT00     chp
# 13      13       0.0  0.549245 2009-01-01 13:00:00  AT00     chp
# 14      14       0.0  0.549245 2009-01-01 14:00:00  AT00     chp
# 15      15       0.0  0.549245 2009-01-01 15:00:00  AT00     chp
# 16      16       0.0  0.549245 2009-01-01 16:00:00  AT00     chp
# 17      17       0.0  0.549245 2009-01-01 17:00:00  AT00     chp
# 18      18       0.0  0.549245 2009-01-01 18:00:00  AT00     chp
# 19      19       0.0  0.549245 2009-01-01 19:00:00  AT00     chp
# 9   chp-gas-ccgt-old-1-other-70.65eur
# 10  chp-gas-ccgt-old-1-other-70.65eur
# 11  chp-gas-ccgt-old-1-other-70.65eur
# 12  chp-gas-ccgt-old-1-other-70.65eur
# 13  chp-gas-ccgt-old-1-other-70.65eur
# 14  chp-gas-ccgt-old-1-other-70.65eur
# 15  chp-gas-ccgt-old-1-other-70.65eur
# 16  chp-gas-ccgt-old-1-other-70.65eur
# 17  chp-gas-ccgt-old-1-other-70.65eur
# 18  chp-gas-ccgt-old-1-other-70.65eur
# 19  chp-gas-ccgt-old-1-other-70.65eur
# 20  chp-gas-ccgt-old-1-other-70.65eur
# 21  chp-gas-ccgt-old-1-other-70.65eur
# 22  chp-gas-ccgt-old-1-other-70.65eur
# 23  chp-gas-ccgt-old-1-other-70.65eur
# 24  chp-gas-ccgt-old-1-other-70.65eur
# 25  chp-gas-ccgt-old-1-other-70.65eur
# 26  chp-gas-ccgt-old-1-other-70.65eur
# 27  chp-gas-ccgt-old-1-other-70.65eur
# 28  chp-gas-ccgt-old-1-other-70.65eur
# 29  chp-gas-ccgt-old-1-other-70.65eur
# 30  chp-gas-ccgt-old-1-other-70.65eur
# 31  chp-gas-ccgt-old-1-other-70.65eur
# 32  chp-gas-ccgt-old-1-other-70.65eur
# 33  chp-gas-ccgt-old-1-other-70.65eur
# 34  chp-gas-ccgt-old-1-other-70.65eur
# 35  chp-gas-ccgt-old-1-other-70.65eur
# 36  chp-gas-ccgt-old-1-other-70.65eur
# 37  chp-gas-ccgt-old-1-other-70.65eur
# 38  chp-gas-ccgt-old-1-other-70.65eur
# 39  chp-gas-ccgt-old-1-other-70.65eur
# 40  chp-gas-ccgt-old-1-other-70.65eur
# 41  chp-gas-ccgt-old-1-other-70.65eur
# 42  chp-gas-ccgt-old-1-other-70.65eur
# 43  chp-gas-ccgt-old-1-other-70.65eur
# 44  chp-gas-ccgt-old-1-other-70.65eur
# 45  chp-gas-ccgt-old-1-other-70.65eur
# 46  chp-gas-ccgt-old-1-other-70.65eur
# 47  chp-gas-ccgt-old-1-other-70.65eur
# 48  chp-gas-ccgt-old-1-other-70.65eur
# 49  chp-gas-ccgt-old-1-other-70.65eur
# 50  chp-gas-ccgt-old-1-other-70.65eur
# 51  chp-gas-ccgt-old-1-other-70.65eur
# 52  chp-gas-ccgt-old-1-other-70.65eur
# 53  chp-gas-ccgt-old-1-other-70.65eur
# 54  chp-gas-ccgt-old-1-other-70.65eur
# 55  chp-gas-ccgt-old-1-other-70.65eur
# 56  chp-gas-ccgt-old-1-other-70.65eur
# 57  chp-gas-ccgt-old-1-other-70.65eur
# 58  chp-gas-ccgt-old-1-other-70.65eur
# 59  chp-gas-ccgt-old-1-other-70.65eur
# 60  chp-gas-ccgt-old-1-other-70.65eur
# 61  chp-gas-ccgt-old-1-other-70.65eur
# 62  chp-gas-ccgt-old-1-other-70.65eur
# 63  chp-gas-ccgt-old-1-other-70.65eur
# 64  chp-gas-ccgt-old-1-other-70.65eur
# 65  chp-gas-ccgt-old-1-other-70.65eur
# 66  chp-gas-ccgt-old-1-other-70.65eur
# 67  chp-gas-ccgt-old-1-other-70.65eur
# 68  chp-gas-ccgt-old-1-other-70.65eur
# 69  chp-gas-ccgt-old-1-other-70.65eur
# 70  chp-gas-ccgt-old-1-other-70.65eur
# 71  chp-gas-ccgt-old-1-other-70.65eur
# 72  chp-gas-ccgt-old-1-other-70.65eur
# 73  chp-gas-ccgt-old-1-other-70.65eur
# 74  chp-gas-ccgt-old-1-other-70.65eur
# 75  chp-gas-ccgt-old-1-other-70.65eur
# 76  chp-gas-ccgt-old-1-other-70.65eur
# 77  chp-gas-ccgt-old-1-other-70.65eur
# 78  chp-gas-ccgt-old-1-other-70.65eur
# 79  chp-gas-ccgt-old-1-other-70.65eur
# 80  chp-gas-ccgt-old-1-other-70.65eur
# 81  chp-gas-ccgt-old-1-other-70.65eur
# 82  chp-gas-ccgt-old-1-other-70.65eur
# 83  chp-gas-ccgt-old-1-other-70.65eur
# 84  chp-gas-ccgt-old-1-other-70.65eur
# 85  chp-gas-ccgt-old-1-other-70.65eur
# 86  chp-gas-ccgt-old-1-other-70.65eur
# 87  chp-gas-ccgt-old-1-other-70.65eur
# 88  chp-gas-ccgt-old-1-other-70.65eur
# 89  chp-gas-ccgt-old-1-other-70.65eur
# 90  chp-gas-ccgt-old-1-other-70.65eur
# 91  chp-gas-ccgt-old-1-other-70.65eur
# 92  chp-gas-ccgt-old-1-other-70.65eur
# 93  chp-gas-ccgt-old-1-other-70.65eur
# 94  chp-gas-ccgt-old-1-other-70.65eur
# 95  chp-gas-ccgt-old-1-other-70.65eur
# 96  chp-gas-ccgt-old-1-other-70.65eur
# 97  chp-gas-ccgt-old-1-other-70.65eur
# 98  chp-gas-ccgt-old-1-other-70.65eur
# 99  chp-gas-ccgt-old-1-other-70.65eur

# %% [markdown]
# ## 8. Assign marginal cost to generators from `costs_2030_processed.csv`
#
# We join the PEMMDB capacity table with the technology costs using `carrier` as the key.
# `marginal_cost` in the costs file already includes fuel + VOM (in €/MWh_el).

# %%
# COSTS_CSV = BASE_DIR / "data/open-tyndp/costs_2030_processed.csv"

# costs = (
#     pd.read_csv(COSTS_CSV, index_col=0)
#     [["marginal_cost", "capital_cost", "VOM", "CO2 intensity", "efficiency"]]
#     .rename(columns={"efficiency": "efficiency_costs"})   # avoid clash with caps.efficiency
# )
# costs.index.name = "cost_tech"

# caps = pd.read_csv(OUT_CAPACITIES)   # has: carrier, index_carrier, open_tyndp_type, bus, p_nom, efficiency, ...

# # Map open_tyndp_type → cost technology name.
# # open_tyndp_type matches costs index directly for gas subtypes and oils.
# # For coal/lignite subtypes (coal-old1, coal-new ...) there is no subtype in costs → fall back to carrier.
# # uranium → nuclear (PEMMDB name vs costs name).
# OPEN_TYNDP_TYPE_TO_COST = {
#     "gas-ccgt":     "gas-ccgt",
#     "gas-conv":     "gas-conv",
#     "gas-ocgt":     "gas-ocgt",
#     "gas-ccgt-ccs": "gas-ccgt-ccs",
#     "oil-light":    "oil-light",
#     "oil-heavy":    "oil-heavy",
#     "oil-shale":    "oil-shale",
#     "nuclear":      "nuclear",
#     "h2-ccgt":      "gas-ccgt",   # same combustion tech, different fuel
# }

# def resolve_cost_tech(row):
#     if row["open_tyndp_type"] in OPEN_TYNDP_TYPE_TO_COST:
#         return OPEN_TYNDP_TYPE_TO_COST[row["open_tyndp_type"]]
#     if row["carrier"] == "uranium":
#         return "nuclear"
#     return row["carrier"]   # coal, lignite, etc. → direct match

# caps["cost_tech"] = caps.apply(resolve_cost_tech, axis=1)

# result = caps.merge(
#     costs[["marginal_cost", "capital_cost", "VOM", "CO2 intensity", "efficiency_costs"]].reset_index(),
#     on="cost_tech",
#     how="left",
# )

# display_cols = ["bus", "carrier", "open_tyndp_type", "p_nom", "cost_tech",
#                 "marginal_cost", "VOM", "CO2 intensity", "efficiency_costs", "capital_cost"]
# summary = (
#     result[display_cols]
#     .query("p_nom > 0 and marginal_cost.notna()", engine="python")
#     .sort_values(["carrier", "open_tyndp_type", "bus"])
#     .reset_index(drop=True)
# )
# Out:
# Generators with p_nom > 0 and matched marginal cost: 355
#       bus  carrier open_tyndp_type         p_nom cost_tech  marginal_cost  \
# 0    AT00  battery  battery-charge     67.757560   battery       0.000000
# 1    BE00  battery  battery-charge    594.358400   battery       0.000000
# 2    BG00  battery  battery-charge   1500.000000   battery       0.000000
# 3    CH00  battery  battery-charge   1221.283571   battery       0.000000
# 4    CZ00  battery  battery-charge    637.300000   battery       0.000000
# ..    ...      ...             ...           ...       ...            ...
# 350  SI00  uranium         nuclear    696.000000   nuclear       1.156126
# 351  SK00  uranium         nuclear   2814.637264   nuclear       1.156126
# 352  TR00  uranium         nuclear   4460.000000   nuclear       1.156126
# 353  UA00  uranium         nuclear  13835.000000   nuclear       1.156126
# 354  UK00  uranium         nuclear   5510.000000   nuclear       1.156126
#
#         VOM  CO2 intensity  efficiency_costs   capital_cost
# 0       NaN            0.0               NaN  102544.684043
# 1       NaN            0.0               NaN  102544.684043
# 2       NaN            0.0               NaN  102544.684043
# 3       NaN            0.0               NaN  102544.684043
# 4       NaN            0.0               NaN  102544.684043
# ..      ...            ...               ...            ...
# 350  3.5464            0.0             0.326  245733.654187
# 351  3.5464            0.0             0.326  245733.654187
# 352  3.5464            0.0             0.326  245733.654187
# 353  3.5464            0.0             0.326  245733.654187
# 354  3.5464            0.0             0.326  245733.654187
#
# [355 rows x 10 columns]

# %%
# print(f"Generators with p_nom > 0 and matched marginal cost: {len(summary)}")
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
# summary.head(100)
# Out:
# Generators with p_nom > 0 and matched marginal cost: 355
#      bus  carrier    open_tyndp_type         p_nom cost_tech  marginal_cost  \
# 0   AT00  battery     battery-charge     67.757560   battery       0.000000
# 1   BE00  battery     battery-charge    594.358400   battery       0.000000
# 2   BG00  battery     battery-charge   1500.000000   battery       0.000000
# 3   CH00  battery     battery-charge   1221.283571   battery       0.000000
# 4   CZ00  battery     battery-charge    637.300000   battery       0.000000
# 5   DE00  battery     battery-charge   3200.400000   battery       0.000000
# 6   DKW1  battery     battery-charge    160.000000   battery       0.000000
# 57  LT00  battery  battery-discharge   1200.000000   battery       0.000000
# 58  LUG1  battery  battery-discharge     25.000000   battery       0.000000
# 59  LV00  battery  battery-discharge     80.000000   battery       0.000000
# 60  NL00  battery  battery-discharge   9331.000000   battery       0.000000
# 61  RO00  battery  battery-discharge    400.000000   battery       0.000000
# 62  SE01  battery  battery-discharge     11.542673   battery       0.000000
# 63  SE02  battery  battery-discharge     11.129541   battery       0.000000
# 64  SE03  battery  battery-discharge    161.723074   battery       0.000000
# 65  SE04  battery  battery-discharge     70.539631   battery       0.000000
# 66  SI00  battery  battery-discharge    606.800000   battery       0.000000
# 67  SK00  battery  battery-discharge    266.000000   battery       0.000000
# 68  UK00  battery  battery-discharge  15065.542000   battery       0.000000
# 69  UKNI  battery  battery-discharge    441.000000   battery       0.000000
# 70  BE00     coal               coal    354.400000      coal       1.160987
# 71  CZ00     coal               coal     45.000000      coal       1.160987
# 72  DKE1     coal               coal    485.520000      coal       1.160987
# 73  DKE1     coal               coal    250.000000      coal       1.160987
# 74  DKE1     coal               coal    430.000000      coal       1.160987
# 75  DKW1     coal               coal    421.066343      coal       1.160987
# 76  DKW1     coal               coal    357.000000      coal       1.160987
# 77  FI00     coal               coal    268.000000      coal       1.160987
# 78  FI00     coal               coal    456.000000      coal       1.160987
# 79  FI00     coal               coal    472.000000      coal       1.160987
# 80  HR00     coal               coal    290.000000      coal       1.160987
# 81  HU00     coal               coal    102.100000      coal       1.160987
# 82  MA00     coal               coal    280.000000      coal       1.160987
# 83  MA00     coal               coal   2236.000000      coal       1.160987
# 84  MA00     coal               coal   1250.000000      coal       1.160987
# 85  MD00     coal               coal    760.000000      coal       1.160987
# 86  PL00     coal               coal   7367.980000      coal       1.160987
# 87  PL00     coal               coal   3276.210000      coal       1.160987
# 88  PL00     coal               coal   1663.000000      coal       1.160987
# 89  RO00     coal               coal    130.000000      coal       1.160987
# 90  SI00     coal               coal     81.000000      coal       1.160987
# 91  SK00     coal               coal     27.085000      coal       1.160987
# 92  SK00     coal               coal    263.441000      coal       1.160987
# 93  TR00     coal               coal   3750.000000      coal       1.160987
# 94  TR00     coal               coal   5980.000000      coal       1.160987
# 95  TR00     coal               coal   1320.000000      coal       1.160987
# 96  UA00     coal               coal  19797.000000      coal       1.160987
# 97  AL00      gas           gas-ccgt    100.000000  gas-ccgt       2.577810
# 98  AL00      gas           gas-ccgt    200.000000  gas-ccgt       2.577810
# 99  AT00      gas           gas-ccgt    356.500000  gas-ccgt       2.577810
#
#        VOM  CO2 intensity  efficiency_costs   capital_cost
# 0      NaN         0.0000               NaN  102544.684043
# 1      NaN         0.0000               NaN  102544.684043
# 2      NaN         0.0000               NaN  102544.684043
# 3      NaN         0.0000               NaN  102544.684043
# 4      NaN         0.0000               NaN  102544.684043
# 5      NaN         0.0000               NaN  102544.684043
# 6      NaN         0.0000               NaN  102544.684043
# 7      NaN         0.0000               NaN  102544.684043
# 8      NaN         0.0000               NaN  102544.684043
# 9      NaN         0.0000               NaN  102544.684043
# 76  3.2612         0.3361             0.356  120046.057771
# 77  3.2612         0.3361             0.356  120046.057771
# 78  3.2612         0.3361             0.356  120046.057771
# 79  3.2612         0.3361             0.356  120046.057771
# 80  3.2612         0.3361             0.356  120046.057771
# 81  3.2612         0.3361             0.356  120046.057771
# 82  3.2612         0.3361             0.356  120046.057771
# 83  3.2612         0.3361             0.356  120046.057771
# 84  3.2612         0.3361             0.356  120046.057771
# 85  3.2612         0.3361             0.356  120046.057771
# 86  3.2612         0.3361             0.356  120046.057771
# 87  3.2612         0.3361             0.356  120046.057771
# 88  3.2612         0.3361             0.356  120046.057771
# 89  3.2612         0.3361             0.356  120046.057771
# 90  3.2612         0.3361             0.356  120046.057771
# 91  3.2612         0.3361             0.356  120046.057771
# 92  3.2612         0.3361             0.356  120046.057771
# 93  3.2612         0.3361             0.356  120046.057771
# 94  3.2612         0.3361             0.356  120046.057771
# 95  3.2612         0.3361             0.356  120046.057771
# 96  3.2612         0.3361             0.356  120046.057771
# 97  4.4445         0.1980             0.580   60777.052054
# 98  4.4445         0.1980             0.580   60777.052054
# 99  4.4445         0.1980             0.580   60777.052054

# %% [markdown]
# ## 9. Compute marginal cost from first principles and save `new_technologies_2030.csv`
#
# Replicates the logic from `create_technologies_costs_dataset.ipynb`:
#
# $$MC = VOM + \frac{fuel\_price}{efficiency} + \frac{CO_2\_emissions}{efficiency} \times CO_2\_price$$
#
# **Inputs:**
# - `costs_2030_processed.csv` — efficiency, VOM
# - TYNDP 2024 Study fuel prices (€/GJ → ×3.6 → €/MWh)
# - TYNDP 2024 CO2 emission factors (kgCO₂/GJ → ×3.6/1000 → tCO₂/MWh)
# - CO₂ price: **113.4 €/tCO₂**
#
# **Output:** `data/open-tyndp/my_technologies_2030.csv`

# %%
# OUT_TECHNOLOGIES = BASE_DIR / "data/open-tyndp/my_technologies_2030.csv"

# # --- TYNDP 2024 Study values ---
# STUDY_FUEL_PRICES = {          # €/GJ
#     "nuclear":   1.7,
#     "coal":      1.8,
#     "lignite":   1.8,
#     "gas":       6.3,
#     "oil-heavy": 9.6,
#     "oil-light": 11.7,
#     "oil-shale": 1.9,
#     "h2":        17.6,
# }
# STUDY_CO2_EMISSIONS = {        # kgCO2/GJ
#     "nuclear":      0.0,
#     "coal":        94.0,   "coal-ccs":     9.4,
#     "lignite":    101.0,   "lignite-ccs": 10.1,
#     "gas":         51.57,  "gas-ccs":      5.70,
#     "oil-light":   78.0,
#     "oil-heavy":   78.0,
#     "oil-shale":  100.0,
#     "h2":           0.0,
# }
# CO2_PRICE = 113.4              # €/tCO2

# HARDCODED_MC = {
#     "other-res": 45.0,         # biomass/waste — no fuel price in TYNDP, set explicitly
# }

# # --- Mapping: open_tyndp_type → (base_fuel, emission_type, costs_tech) ---
# # base_fuel    → fuel price lookup
# # emission_type → CO2 emission lookup  (differs from base_fuel for CCS)
# # costs_tech   → costs_2030_processed.csv technology name
# TYPE_PARAMS = {
#     "nuclear":       ("nuclear",   "nuclear",      "nuclear"),
#     "coal":          ("coal",      "coal",         "coal"),
#     "coal-ccs":      ("coal",      "coal-ccs",     "coal-ccs"),
#     "lignite":       ("lignite",   "lignite",      "lignite"),
#     "lignite-ccs":   ("lignite",   "lignite-ccs",  "lignite-ccs"),
#     "gas-ccgt":      ("gas",       "gas",          "gas-ccgt"),
#     "gas-conv":      ("gas",       "gas",          "gas-conv"),
#     "gas-ocgt":      ("gas",       "gas",          "gas-ocgt"),
#     "gas-ccgt-ccs":  ("gas",       "gas-ccs",      "gas-ccgt-ccs"),
#     "oil-light":     ("oil-light", "oil-light",    "oil-light"),
#     "oil-heavy":     ("oil-heavy", "oil-heavy",    "oil-heavy"),
#     "oil-shale":     ("oil-shale", "oil-shale",    "oil-shale"),
#     "h2-ccgt":       ("h2",        "h2-ccgt",      "gas-ccgt"),   # H2 combustion ≈ CCGT efficiency
#     "chp":           ("gas",       "gas",          "central gas CHP"),
#     "other-res":     (None,        None,           None),
#     "dsr":           (None,        None,           None),
# }

# # --- Load costs CSV (efficiency + VOM) ---
# costs_full = pd.read_csv(COSTS_CSV, index_col=0)

# def lookup_costs(tech_name):
#     """Return (efficiency, VOM) for a given costs-CSV technology name."""
#     if tech_name and tech_name in costs_full.index:
#         row = costs_full.loc[tech_name]
#         eff = float(row["efficiency"]) if pd.notna(row["efficiency"]) else 1.0
#         vom = float(row["VOM"])        if pd.notna(row["VOM"])        else 0.0
#         return eff, vom
#     return 1.0, 0.0

# # --- Load capacities (one row per bus × open_tyndp_type) ---
# caps = pd.read_csv(OUT_CAPACITIES)

# # Keep only unique (carrier, open_tyndp_type) combinations — MC is the same for all buses
# unique_types = (
#     caps[["carrier", "open_tyndp_type"]]
#     .drop_duplicates()
#     .reset_index(drop=True)
# )

# # --- Build dataset ---
# rows_out = []
# for _, row in unique_types.iterrows():
#     carrier    = row["carrier"]
#     otype      = row["open_tyndp_type"]

#     params = TYPE_PARAMS.get(otype) or TYPE_PARAMS.get(carrier)
#     if params is None:
#         base_fuel, emission_type, costs_tech = None, None, None
#     else:
#         base_fuel, emission_type, costs_tech = params

#     eff, vom = lookup_costs(costs_tech)

#     # Marginal cost calculation
#     if base_fuel:
#         fuel_price_gj  = STUDY_FUEL_PRICES.get(base_fuel, 0.0)
#         fuel_price_mwh = fuel_price_gj * 3.6
#         co2_kg_gj      = STUDY_CO2_EMISSIONS.get(emission_type, 0.0)
#         co2_tco2_mwh   = co2_kg_gj * 3.6 / 1000.0
#         fuel_cost      = fuel_price_mwh / eff if eff > 0 else 0.0
#         co2_cost       = (co2_tco2_mwh / eff) * CO2_PRICE if eff > 0 else 0.0
#         mc             = vom + fuel_cost + co2_cost
#     else:
#         fuel_price_gj = fuel_price_mwh = 0.0
#         co2_kg_gj = co2_tco2_mwh = 0.0
#         mc = vom

#     # Hardcoded override (e.g. other-res biomass)
#     if carrier in HARDCODED_MC:
#         mc = HARDCODED_MC[carrier]

#     rows_out.append({
#         "carrier":            carrier,
#         "open_tyndp_type":    otype,
#         "costs_technology":   costs_tech or "",
#         "fuel_type":          base_fuel  or "renewable",
#         "emission_type":      emission_type or "renewable",
#         "efficiency":         round(eff, 4),
#         "vom_eur_mwh":        round(vom, 4),
#         "fuel_price_eur_gj":  round(fuel_price_gj,  4),
#         "fuel_price_eur_mwh": round(fuel_price_mwh, 4),
#         "co2_kg_gj":          round(co2_kg_gj,      4),
#         "co2_tco2_mwh":       round(co2_tco2_mwh,   6),
#         "co2_price_eur_tco2": CO2_PRICE,
#         "marginal_cost_eur_mwh": round(mc, 4),
#     })

# new_tech = pd.DataFrame(rows_out).sort_values(["carrier", "open_tyndp_type"]).reset_index(drop=True)
# new_tech.to_csv(OUT_TECHNOLOGIES, index=False)

# print(f"Saved: {OUT_TECHNOLOGIES}  ({len(new_tech)} technology types)")
# print()
# new_tech
# Out:
# Saved: /Users/radovanhodor/Documents/TUKE/Final diplomova praca/data/open-tyndp/my_technologies_2030.csv  (32 technology types)
#             carrier            open_tyndp_type costs_technology  fuel_type  \
# 0           battery             battery-charge                   renewable
# 1           battery          battery-discharge                   renewable
# 2           battery              battery-store                   renewable
# 3               chp                        NaN  central gas CHP        gas
# 4              coal                       coal             coal       coal
# 5              coal                   coal-ccs         coal-ccs       coal
# 6               dsr                        NaN                   renewable
# 7               gas                   gas-ccgt         gas-ccgt        gas
# 8               gas               gas-ccgt-ccs     gas-ccgt-ccs        gas
# 9               gas                   gas-conv         gas-conv        gas
# 10              gas                   gas-ocgt         gas-ocgt        gas
# 11          h2-ccgt                    h2-ccgt         gas-ccgt         h2
# 12     h2-fuel-cell               h2-fuel-cell                   renewable
# 13        hydro-phs             hydro-phs-pump                   renewable
# 14        hydro-phs        hydro-phs-reservoir                   renewable
# 15        hydro-phs          hydro-phs-turbine                   renewable
# 16   hydro-phs-pure        hydro-phs-pure-pump                   renewable
# 17   hydro-phs-pure   hydro-phs-pure-reservoir                   renewable
# 18   hydro-phs-pure     hydro-phs-pure-turbine                   renewable
# 19    hydro-pondage    hydro-pondage-reservoir                   renewable
# 20    hydro-pondage      hydro-pondage-turbine                   renewable
# 21  hydro-reservoir  hydro-reservoir-reservoir                   renewable
# 22  hydro-reservoir    hydro-reservoir-turbine                   renewable
# 23        hydro-ror          hydro-ror-turbine                   renewable
# 24          lignite                    lignite          lignite    lignite
# 25          lignite                lignite-ccs      lignite-ccs    lignite
# 26        oil-heavy                  oil-heavy        oil-heavy  oil-heavy
# 27        oil-light                  oil-light        oil-light  oil-light
# 28        oil-shale                  oil-shale        oil-shale  oil-shale
# 29        other-res                  other-res                   renewable
# 30          uranium                    nuclear          nuclear    nuclear
# 31              NaN                        NaN                   renewable
#
#    emission_type  efficiency  vom_eur_mwh  fuel_price_eur_gj  \
# 0      renewable       1.000       0.0000                0.0
# 1      renewable       1.000       0.0000                0.0
# 2      renewable       1.000       0.0000                0.0
# 3            gas       0.410       4.4445                6.3
# 4           coal       0.356       3.2612                1.8
# 5       coal-ccs       0.356       3.2612                1.8
# 6      renewable       1.000       0.0000                0.0
# 7            gas       0.580       4.4445                6.3
# 8        gas-ccs       0.580       4.4445                6.3
# 9            gas       0.410       4.7620                6.3
# 10           gas       0.410       4.7620                6.3
# 11       h2-ccgt       0.580       4.4445               17.6
# 12     renewable       1.000       0.0000                0.0
# 13     renewable       1.000       0.0000                0.0
# 14     renewable       1.000       0.0000                0.0
# 15     renewable       1.000       0.0000                0.0
# 16     renewable       1.000       0.0000                0.0
# 17     renewable       1.000       0.0000                0.0
# 18     renewable       1.000       0.0000                0.0
# 19     renewable       1.000       0.0000                0.0
# 20     renewable       1.000       0.0000                0.0
# 21     renewable       1.000       0.0000                0.0
# 22     renewable       1.000       0.0000                0.0
# 23     renewable       1.000       0.0000                0.0
# 24       lignite       0.330       3.2612                1.8
# 25   lignite-ccs       0.330       3.2612                1.8
# 26     oil-heavy       0.350       6.3493                9.6
# 27     oil-light       0.350       6.3493               11.7
# 28     oil-shale       0.350       6.3493                1.9
# 29     renewable       1.000       0.0000                0.0
# 30       nuclear       0.326       3.5464                1.7
# 31     renewable       1.000       0.0000                0.0
#
#     fuel_price_eur_mwh  co2_kg_gj  co2_tco2_mwh  co2_price_eur_tco2  \
# 0                 0.00       0.00      0.000000               113.4
# 1                 0.00       0.00      0.000000               113.4
# 2                 0.00       0.00      0.000000               113.4
# 3                22.68      51.57      0.185652               113.4
# 4                 6.48      94.00      0.338400               113.4
# 5                 6.48       9.40      0.033840               113.4
# 6                 0.00       0.00      0.000000               113.4
# 7                22.68      51.57      0.185652               113.4
# 8                22.68       5.70      0.020520               113.4
# 9                22.68      51.57      0.185652               113.4
# 10               22.68      51.57      0.185652               113.4
# 11               63.36       0.00      0.000000               113.4
# 12                0.00       0.00      0.000000               113.4
# 13                0.00       0.00      0.000000               113.4
# 14                0.00       0.00      0.000000               113.4
# 15                0.00       0.00      0.000000               113.4
# 16                0.00       0.00      0.000000               113.4
# 17                0.00       0.00      0.000000               113.4
# 18                0.00       0.00      0.000000               113.4
# 19                0.00       0.00      0.000000               113.4
# 20                0.00       0.00      0.000000               113.4
# 21                0.00       0.00      0.000000               113.4
# 22                0.00       0.00      0.000000               113.4
# 23                0.00       0.00      0.000000               113.4
# 24                6.48     101.00      0.363600               113.4
# 25                6.48      10.10      0.036360               113.4
# 26               34.56      78.00      0.280800               113.4
# 27               42.12      78.00      0.280800               113.4
# 28                6.84     100.00      0.360000               113.4
# 29                0.00       0.00      0.000000               113.4
# 30                6.12       0.00      0.000000               113.4
# 31                0.00       0.00      0.000000               113.4
#
#     marginal_cost_eur_mwh
# 0                  0.0000
# 1                  0.0000
# 2                  0.0000
# 3                111.1102
# 4                129.2572
# 5                 32.2428
# 6                  0.0000
# 7                 79.8461
# 8                 47.5600
# 9                111.4277
# 10               111.4277
# 11               113.6859
# 12                 0.0000
# 13                 0.0000
# 14                 0.0000
# 15                 0.0000
# 16                 0.0000
# 17                 0.0000
# 18                 0.0000
# 19                 0.0000
# 20                 0.0000
# 21                 0.0000
# 22                 0.0000
# 23                 0.0000
# 24               147.8437
# 25                35.3922
# 26               196.0714
# 27               217.6714
# 28               142.5322
# 29                45.0000
# 30                22.3194
# 31                 0.0000
